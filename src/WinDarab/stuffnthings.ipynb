# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import yaml

import getters
# import functions

## import characterizations (python dictionary structure)
pack = getters.Pack("characterization/pack.yaml")
motor = getters.Motor("characterization/motor.yaml")
motor_controller = getters.MotorController("characterization/motor_controller.yaml")
vehicle = getters.Vehicle("characterization/vehicle.yaml")
track = getters.Track("characterization/track.yaml")

sim = getters.Simulation(vehicle, motor, pack, track)

# %%
## method to calculate energy consumption
## include drivetrain efficiency
## include motor efficiency
## include inverter efficiency

## input for track map possibly, with speeds at different areas of the track 
## **(better to not use average speed, isn't really a good thing to look at for energy usage)

## would be cool to look into where the components/systems are the MOST efficient, assuming minimum efficiency is aight for now
# trackMap = ...

# batteryPack = ... ## create some type of datatype to characterize the pack (max voltage, voltage sag, and other things)

## motor enforces torque-speed curve
## controller enforces current limit
## accumulator enforces voltage sag
## final DC power = mechanical power + motor + controller losses
# Run simulation

# print(track.air_density)
print(track.segments[0])

sim.simulate_segment(track.segments[0])
print(sim.simulate_segment(track.segments[0]))
# Out:
# {'name': 'straight_1', 'type': 'straight', 'length_m': 90, 'target_speed_mps': 10, 'throttle': 1}
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# 230 0.0
# ...
